# %% [markdown]
# <a href="https://colab.research.google.com/github/JotaBlanco/QuixStreamsNotebooks/blob/main/Workshops/Scandio/Quix_Streams_PROCESS_CHAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Quix Streams
# Just use pip install to download the Quix Streams library.
#
# [Quix Streams](https://github.com/quixio/quix-streams) is an open source Python library for processing streaming data. It’s aimed at people who work with time-series data streams — from developers and ML engineers to data scientists and data engineers.

# %%
! pip install quixstreams
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting quixstreams
#   Downloading quixstreams-0.5.4-py3-none-manylinux2014_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from quixstreams) (1.5.3)
# Collecting Deprecated<2,>=1.1 (from quixstreams)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated<2,>=1.1->quixstreams) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2,>=1.0.0->quixstreams) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2,>=1.0.0->quixstreams) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2,>=1.0.0->quixstreams) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2,>=1.0.0->quixstreams) (1.16.0)
# Installing collected packages: Deprecated, quixstreams
# Successfully installed Deprecated-1.2.14 quixstreams-0.5.4

# %% [markdown]
# # Import the libraries
# We will be using mainly pandas, quix, matplotlib and seaborn.

# %%
import pandas as pd
import quixstreams as qx

# %% [markdown]
# # 1 - Create client
# Let's start by creating a Quix client that we'll use to publish and subscribe to Kafka topics.

# %%
# Initiating Quix managed token, but it could be your own kafka
token = 'sdk-296f2b9decff4770a525ff7d8855a78d'
client = qx.QuixStreamingClient(token)
client

# %% [markdown]
# # 2 - Clients
# Create producer and consumer clients

# %%
topic_name = "chat-messages-enriched"
topic_producer = client.get_topic_producer(topic_name)
topic_producer

# %%
stream_id = "scandio"
stream_out = topic_producer.get_or_create_stream(stream_id)
stream_out

# %%
topic_name = "chat-messages"
topic_consumer = client.get_topic_consumer(topic_name)
topic_consumer

# %% [markdown]
# # 3 - Listen to some data
# Let's listen to some data

# %%
df= pd.DataFrame()

def on_stream_received_handler(stream_received: qx.StreamConsumer):
  stream_received.timeseries.on_dataframe_received = on_timeseries_data_received_handler

def on_timeseries_data_received_handler(stream: qx.StreamConsumer, df_i: pd.DataFrame):
  global df
  df = df.append(df_i)
  print("Data from stream " + stream.stream_id)
  display(df_i)

topic_consumer = client.get_topic_consumer(topic_name)
topic_consumer.on_stream_received = on_stream_received_handler
qx.App.run()
# Out:
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686654590865000000           hi   scandio  Customer  Javier PC
#
#   TAG__email
# 0
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp       chat-message TAG__room TAG__role  TAG__name  \
# 0  1686654594915000000  this is a message   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email
# 0
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686654597284000000        hello   scandio  Customer  Javier PC
#
#   TAG__email
# 0
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686654599354000000   happy days   scandio  Customer  Javier PC
#
#   TAG__email
# 0
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686654601695000000  sad message   scandio  Customer  Javier PC
#
#   TAG__email
# 0
# Data from stream scandio
# <ipython-input-7-ca5b122323bc>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_i)
#              timestamp       chat-message TAG__room TAG__role  TAG__name  \
# 0  1686654604396000000  let's do one more   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email
# 0

# %%
df
# Out:
#              timestamp       chat-message TAG__room TAG__role  TAG__name  \
# 0  1686654590865000000                 hi   scandio  Customer  Javier PC
# 0  1686654594915000000  this is a message   scandio  Customer  Javier PC
# 0  1686654597284000000              hello   scandio  Customer  Javier PC
# 0  1686654599354000000         happy days   scandio  Customer  Javier PC
# 0  1686654601695000000        sad message   scandio  Customer  Javier PC
# 0  1686654604396000000  let's do one more   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# # 4 - Process data with Hugging Face

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.30.1-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 86.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 94.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.1

# %%
from transformers import pipeline

# %%
pipeline_model = pipeline(model='siebert/sentiment-roberta-large-english')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
pd.DataFrame(pipeline_model(["This is analysing text", "Two messages"]))
# Out:
#       label     score
# 0  POSITIVE  0.985885
# 1  NEGATIVE  0.996774

# %%
prediction = pipeline_model("This is analysing text")[0]
prediction["label"], prediction["score"]
# Out:
# ('POSITIVE', 0.9858850240707397)

# %% [markdown]
# ## 4.1 - Processing without state

# %%
topic_producer = client.get_topic_producer("chat-messages-enriched")
stream_out = topic_producer.get_or_create_stream(stream_id)

def on_stream_received_handler(stream_received: qx.StreamConsumer):
  stream_received.timeseries.on_dataframe_received = on_timeseries_data_received_handler

def on_timeseries_data_received_handler(stream_in: qx.StreamConsumer, df: pd.DataFrame):

  # Add predictions
  df_prediction = pd.DataFrame(pipeline_model(list(df["chat-message"])))
  df = pd.concat([df, df_prediction], axis=1)

  # Sentiment column
  df["sentiment"] = df["score"]
  filter_negative = df["label"] == "NEGATIVE"
  df.loc[filter_negative, "sentiment"] = -df.loc[filter_negative, "score"]

  # Average
  #df["average_sentiment"] = df["sentiment"]
  display(df)
  stream_out.timeseries.publish(df)

topic_consumer = client.get_topic_consumer("chat-messages")
topic_consumer.on_stream_received = on_stream_received_handler
qx.App.run()
# Out:
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655084228000000   happy days   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment
# 0             POSITIVE  0.998586   0.998586
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655093050000000  sad message   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment
# 0             NEGATIVE  0.998321  -0.998321

# %% [markdown]
# ## 4.2 - Processing with state

# %%
topic_producer = client.get_topic_producer("chat-messages-enriched")
stream_out = topic_producer.get_or_create_stream(stream_id)

last_X_sent = []

def on_stream_received_handler(stream_received: qx.StreamConsumer):
  stream_received.timeseries.on_dataframe_received = on_timeseries_data_received_handler

def on_timeseries_data_received_handler(stream_in: qx.StreamConsumer, df: pd.DataFrame):
  global last_X_sent

  # Add predictions
  df_prediction = pd.DataFrame(pipeline_model(list(df["chat-message"])))
  df = pd.concat([df, df_prediction], axis=1)

  # Sentiment column
  df["sentiment"] = df["score"]
  filter_negative = df["label"] == "NEGATIVE"
  df.loc[filter_negative, "sentiment"] = -df.loc[filter_negative, "score"]

  # Average
  last_X_sent = last_X_sent + list(df["sentiment"])
  last_X_sent = last_X_sent[-5:]
  df["average_sentiment"] = sum(last_X_sent)/len(last_X_sent)
  display(df)
  stream_out.timeseries.publish(df)

topic_consumer = client.get_topic_consumer("chat-messages")
topic_consumer.on_stream_received = on_stream_received_handler
qx.App.run()
# Out:
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655167721000000           hi   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             POSITIVE  0.994815   0.994815           0.994815
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655174112000000       happy=   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             POSITIVE  0.998671   0.998671           0.996743
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655175131000000          sad   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             NEGATIVE  0.997557  -0.997557           0.331976
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655178553000000       sadder   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             NEGATIVE  0.997871  -0.997871          -0.000485
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655186144000000     bollocks   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             NEGATIVE  0.998601  -0.998601          -0.200109
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655189863000000         ball   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             NEGATIVE  0.866571  -0.866571          -0.572386
#              timestamp    chat-message TAG__room TAG__role  TAG__name  \
# 0  1686655197153000000  happy birthday   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email     label     score  sentiment  average_sentiment
# 0                        POSITIVE  0.998874   0.998874          -0.572345
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655203122000000   happy days   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             POSITIVE  0.998586   0.998586          -0.173117
#              timestamp chat-message TAG__room TAG__role  TAG__name TAG__phone  \
# 0  1686655205642000000        happy   scandio  Customer  Javier PC
#
#   TAG__email     label     score  sentiment  average_sentiment
# 0             POSITIVE  0.998799   0.998799           0.226217
#              timestamp  chat-message TAG__room TAG__role  TAG__name  \
# 0  1686655208523000000  good feeling   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email     label     score  sentiment  average_sentiment
# 0                        POSITIVE  0.998566   0.998566           0.625651
#              timestamp   chat-message TAG__room TAG__role  TAG__name  \
# 0  1686655210591000000  felling great   scandio  Customer  Javier PC
#
#   TAG__phone TAG__email     label   score  sentiment  average_sentiment
# 0                        POSITIVE  0.9986     0.9986           0.998685
